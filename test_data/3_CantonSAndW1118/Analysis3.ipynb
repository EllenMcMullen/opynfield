# %% [markdown]
# # Analysis 3
# This analysis was edited from the opynfield tutorial. Here, we are comparing Canton-S flies with w1118 flies, which have reduced visual acuity. We expect that the w1118 flies will have higher activity as a function of time and coverage than the Canton-S flies, due to their reduced ability to see, and thus learn / habituate to the novel arena boundary.

# %% [markdown]
# ## 1. Import the package and needed functions / classes

# %%
from opynfield.config.user_input import UserInput
from opynfield.config.defaults_settings import Defaults
from opynfield.config.cov_asymptote import CoverageAsymptote
from opynfield.config.model_settings import set_up_fits
from opynfield.config.plot_settings import PlotSettings
from opynfield.readin.run_all import run_all_track_types
from opynfield.calculate_measures.calculate_measures import tracks_to_measures
from opynfield.summarize_measures.summarize_individuals import individual_measures_to_dfs
from opynfield.summarize_measures.summarize_groups import all_group_averages
from opynfield.fit_models.fit_individual_models import fit_all, find_fit_bounds, re_fit_all
from opynfield.fit_models.fit_group_models import group_fit_all
from opynfield.stat_test.stat_test import format_params, format_group_params, run_tests
from opynfield.plotting.plot_individuals import plot_all_individuals, plot_traces
from opynfield.plotting.plot_solo_groups import plot_all_solo_groups
from opynfield.plotting.plot_solo_groups_with_individuals import plot_components_of_solo_groups
from opynfield.plotting.plot_group_comparisons import plot_all_group_comparisons
from opynfield.readin.summary_file import summary_file

from copy import deepcopy

# %% [markdown]
# ## 2. Define the settings to use

# %% [markdown]
# ### 2a. Set up your user inputs

# %%
user_settings = UserInput(groups_and_types = {"CantonS": ["Buridian Tracker"], "w1118": ["Buridian Tracker"]},
                          groups_to_paths = {"CantonS": "CS", "w1118": "white"},
                          arena_radius_cm = 4.2,
                          sample_freq = 30,
                          edge_dist_cm = 1,
                          time_bin_size = 1,
                          inactivity_threshold = 0.001,
                          verbose = True,
                          result_path = '/Users/ellenmcmullen/Documents/GitHub/opynfield/test_data/3_CantonSAndW1118/ExpectedResults')

# %% [markdown]
# ### 2b. Prep the results directory

# %%
user_settings.prep_directory()

# %% [markdown]
# ### 2c. Set up the default settings

# %%
default_settings = Defaults()

# %% [markdown]
# ### 2d. Set up the coverage asymptote settings

# %%
asymptote_settings = CoverageAsymptote()

# %% [markdown]
# ### 2e. Set up the model settings

# %%
model_settings = set_up_fits()

# %% [markdown]
# ### 2f. Set up the plotting settings

# %%
plot_settings = PlotSettings(group_colors={'CantonS': 'b', 'w1118': 'r'},
                             display_individual_figures=True,
                             display_solo_group_figures=True)

# %% [markdown]
# ## 3. Read in your data

# %%
track_list = run_all_track_types(groups_and_types=user_settings.groups_and_types,
                                 verbose=user_settings.verbose,
                                 arena_radius_cm=user_settings.arena_radius_cm,
                                 running_window_length=user_settings.running_window_length,
                                 window_step_size=user_settings.window_step_size,
                                 sample_freq=user_settings.sample_freq,
                                 time_bin_size=user_settings.time_bin_size,
                                 trim=user_settings.trim)
# Out:
# ['Buridian Tracker']
# {'Buridian Tracker': ['CantonS', 'w1118']}
# Read In Buridian Tracker Files For Groups ['CantonS', 'w1118']
# Running Buridian Tracker Files For Group: CantonS
# CantonS, File 1 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 2 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 3 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 4 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 5 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 6 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 7 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 8 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 9 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 10 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 11 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 12 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 13 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 14 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 15 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 16 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 17 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 18 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 19 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 20 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 21 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 22 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 23 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 24 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 25 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 26 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 27 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 28 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 29 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 30 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 31 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 32 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 33 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 34 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 35 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 36 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 37 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 38 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 39 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 40 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 41 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 42 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 43 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 44 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 45 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 46 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 47 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 48 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 49 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 50 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 51 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 52 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 53 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 54 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 55 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 56 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 57 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 58 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 59 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 60 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 61 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 62 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 63 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 64 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 65 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 66 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 67 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# CantonS, File 68 Out Of 68
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# Running Buridian Tracker Files For Group: w1118
# w1118, File 1 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 2 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 3 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 4 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 5 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 6 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 7 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 8 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 9 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 10 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 11 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 12 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 13 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 14 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 15 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 16 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 17 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 18 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 19 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 20 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 21 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 22 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 23 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 24 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 25 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 26 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 27 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 28 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 29 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 30 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 31 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 32 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 33 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 34 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 35 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 36 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 37 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 38 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 39 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 40 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 41 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 42 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 43 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 44 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 45 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 46 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 47 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 48 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 49 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 50 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 51 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 52 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 53 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 54 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 55 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 56 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 57 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 58 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 59 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 60 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 61 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 62 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 63 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 64 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled
# w1118, File 65 Out Of 65
# Buri Units Converted
# Buri Units Centered
# Buri Track Smoothed
# Buri Track Subsampled
# Buri Track Missing Values Filled

# %% [markdown]
# ## 4. Calculate behavioral measures

# %% [markdown]
# ### 4a. Generate the measures

# %%
standard_track_list, tracks_by_groups = tracks_to_measures(all_tracks=track_list,
                                                           user_config=user_settings,
                                                           default_settings=default_settings,
                                                           coverage_settings=asymptote_settings)
# Out:
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# Polar Coordinates Calculated
# Activity Calculated
# Turning Angles Calculated
# Motion Probabilities Calculated
# Coverage Bins Located
# Coverage Calculated
# Percent Coverage Calculated
# PICA Calculated
# All Independent Track Measures Calculated
# Tracks Converted To Standard Tracks
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated
# PGCA Calculated

# %% [markdown]
# ### 4b. Save the measures

# %%
individual_dfs = individual_measures_to_dfs(tracks_by_groups=tracks_by_groups,
                                            defaults=default_settings,
                                            user_inputs=user_settings)
# Out:
# Summarizing Tracks From Group CantonS
# Summarizing Tracks From Group w1118

# %% [markdown]
# ### 4c. Calculate group averages of the measures

# %%
group_averages = all_group_averages(individual_measures_dfs=individual_dfs,
                                    test_defaults=default_settings,
                                    user_config=user_settings)
# Out:
# Averaging Tracks From Group CantonS by time
# Averaging Tracks From Group w1118 by time
# Averaging Tracks From Group CantonS By coverage
# Averaging Tracks From Group w1118 By coverage
# Averaging Tracks From Group CantonS By pica
# Averaging Tracks From Group w1118 By pica
# Averaging Tracks From Group CantonS By pgca
# Averaging Tracks From Group w1118 By pgca
# Averaging Tracks From Group CantonS by percent coverage
# Averaging Tracks From Group w1118 by percent coverage

# %% [markdown]
# ## 5. Fit models to individuals' measures

# %% [markdown]
# ### 5a. Naive bounds

# %%
naive_fits = fit_all(individual_measures_dfs=individual_dfs,
                     defaults=default_settings,
                     model_params=model_settings)
# Out:
# Fitting Models To Tracks From Group CantonS by time
# Fitting Models To Tracks From Group CantonS by coverage
# Fitting Models To Tracks From Group CantonS by pica
# Fitting Models To Tracks From Group CantonS by pgca
# Fitting Models To Tracks From Group CantonS by percent_coverage
# Fitting Models To Tracks From Group w1118 by time
# Fitting Models To Tracks From Group w1118 by coverage
# Fitting Models To Tracks From Group w1118 by pica
# Fitting Models To Tracks From Group w1118 by pgca
# Fitting Models To Tracks From Group w1118 by percent_coverage

# %% [markdown]
# ### 5b. Find new bounds

# %%
upper_bounds, lower_bounds, p0s = find_fit_bounds(fits=naive_fits,
                                                  user_inputs=user_settings)

# %% [markdown]
# ### 5c. Re-fit models

# %%
bounded_fits = re_fit_all(individual_measures_dfs=individual_dfs,
                          defaults=default_settings,
                          model_params=model_settings,
                          upper=upper_bounds,
                          lower=lower_bounds,
                          initial=p0s )
# Out:
# Re-Fitting Models To Tracks From Group CantonS by time
# Re-Fitting Models To Tracks From Group CantonS by coverage
# Re-Fitting Models To Tracks From Group CantonS by pica
# Re-Fitting Models To Tracks From Group CantonS by pgca
# Re-Fitting Models To Tracks From Group CantonS by percent_coverage
# Re-Fitting Models To Tracks From Group w1118 by time
# Re-Fitting Models To Tracks From Group w1118 by coverage
# Re-Fitting Models To Tracks From Group w1118 by pica
# Re-Fitting Models To Tracks From Group w1118 by pgca
# Re-Fitting Models To Tracks From Group w1118 by percent_coverage

# %% [markdown]
# ### 5d. Format and save the bounded individual fits

# %%
formatted_bounded_fits = format_params(bounded_fits=deepcopy(bounded_fits),
                                       defaults=default_settings,
                                       user_inputs=user_settings)

# %% [markdown]
# ## 6. Fit models to group measures

# %% [markdown]
# ### 6a. Fit the group models with bounds

# %%
group_fits = group_fit_all(individual_measures_dfs=individual_dfs,
                           defaults=default_settings,
                           model_params=model_settings,
                           upper=upper_bounds,
                           lower=lower_bounds,
                           initial=p0s)
# Out:
# Fitting Models To Entire Group CantonS by time
# Fitting Models To Entire Group CantonS by coverage
# Fitting Models To Entire Group CantonS by pica
# Fitting Models To Entire Group CantonS by pgca
# Fitting Models To Entire Group CantonS by percent_coverage
# Fitting Models To Entire Group w1118 by time
# Fitting Models To Entire Group w1118 by coverage
# Fitting Models To Entire Group w1118 by pica
# Fitting Models To Entire Group w1118 by pgca
# Fitting Models To Entire Group w1118 by percent_coverage

# %% [markdown]
# ### 6b. Format and save the bounded group fits

# %%
format_group_params(group_fits=deepcopy(group_fits),
                    defaults=default_settings,
                    user_inputs=user_settings)

# %% [markdown]
# ## 7. Run statistical tests

# %%
run_tests(formatted_bounded_fits=formatted_bounded_fits,
          defaults=default_settings,
          user_inputs=user_settings)

# %% [markdown]
# ## 8. Plot the results

# %% [markdown]
# ### 8a. Plot individuals

# %%
plot_all_individuals(measures=individual_dfs,
                     model_params=bounded_fits,
                     model_info=model_settings,
                     defaults=default_settings,
                     plot_settings=plot_settings,
                     user_config=user_settings)
# Out:
# Plotting Individuals From Group CantonS by time
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# ...
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:229: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### 8b. Plot traces

# %%
plot_traces(tracks_by_groups=tracks_by_groups,
            plot_settings=plot_settings,
            user_input=user_settings)
# Out:
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_individuals.py:443: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %% [markdown]
# ### 8c. Plot group averages

# %%
plot_all_solo_groups(group_averages=group_averages,
                     group_fits=group_fits,
                     model_params=model_settings,
                     test_defaults=default_settings,
                     plot_settings=plot_settings,
                     user_config=user_settings)
# Out:
# Plotting Group CantonS by time
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Plotting Group CantonS by coverage
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:297: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Plotting Group CantonS by pica
# Plotting Group CantonS by pgca
# Plotting Group CantonS by percent_coverage
# Plotting Group w1118 by time
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:153: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Plotting Group w1118 by coverage
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups.py:297: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Plotting Group w1118 by pica
# Plotting Group w1118 by pgca
# Plotting Group w1118 by percent_coverage

# %% [markdown]
# ### 8d. Plot group averages with component individuals

# %%
plot_components_of_solo_groups(individuals=individual_dfs,
                               individual_fits=bounded_fits,
                               groups=group_averages,
                               group_fits=group_fits,
                               model_specs=model_settings,
                               defaults=default_settings,
                               plot_settings=plot_settings,
                               user_inputs=user_settings)
# Out:
# Plotting Group And Individuals of CantonS by time
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups_with_individuals.py:267: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Plotting Group And Individuals of CantonS by coverage
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_solo_groups_with_individuals.py:149: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Plotting Group And Individuals of CantonS by pica
# Plotting Group And Individuals of CantonS by pgca
# Plotting Group And Individuals of CantonS by percent_coverage
# Plotting Group And Individuals of w1118 by time
# Plotting Group And Individuals of w1118 by coverage
# Plotting Group And Individuals of w1118 by pica
# Plotting Group And Individuals of w1118 by pgca
# Plotting Group And Individuals of w1118 by percent_coverage

# %% [markdown]
# ### 8e. Plot group average comparisons

# %%
plot_all_group_comparisons(group_averages=group_averages,
                           group_fits=group_fits,
                           model_params=model_settings,
                           test_defaults=default_settings,
                           plot_settings=plot_settings,
                           user_config=user_settings)
# Out:
# Plotting Group Comparisons by time
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_group_comparisons.py:142: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Plotting Group Comparisons by coverage
# /Users/ellenmcmullen/opt/anaconda3/envs/opynfield_run/lib/python3.11/site-packages/opynfield/plotting/plot_group_comparisons.py:255: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Plotting Group Comparisons by pica
# Plotting Group Comparisons by pgca
# Plotting Group Comparisons by percent_coverage

# %% [markdown]
# ## 9. Summarize the run

# %%
summary_file(tracks_by_group=tracks_by_groups,
             test_cov_asymptote=asymptote_settings,
             user_defaults=default_settings,
             model_settings=model_settings,
             plot_settings=plot_settings,
             user_config=user_settings)
# Out:
# Formatting Summary File

# %% [markdown]
# ## You're done!
